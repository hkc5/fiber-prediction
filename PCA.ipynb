# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data= np.loadtxt("featurematrix2.csv", delimiter= ",")
# print(data.shape)
scaler= StandardScaler()
feature_matrix= scaler.fit_transform(data)

# %%
pca= PCA()
principal_components= pca.fit_transform(feature_matrix)
# principal_components= pca.fit_transform(data)
explained_variance = pca.explained_variance_ratio_

plt.plot(np.cumsum(pca.explained_variance_ratio_), "b .")
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.show()

# %%
required_variance= .9
no_components= sum(pca.explained_variance_ratio_.cumsum() < required_variance) + 1

pca_var= PCA(no_components)
principal_matrix= pca_var.fit_transform(feature_matrix)


np.savetxt('principal_matrix.csv', principal_matrix, delimiter=',')
